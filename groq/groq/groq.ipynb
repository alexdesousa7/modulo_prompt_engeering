# %% [markdown]
# # Una plataforma con más modelos: GROQ
#
# Este notebook es una guía de inicio rápido para interactuar con la API de Groq: un proveedor de diferentes modelos LLM con servicio gratuito y sus respectivos rate limits.
#
# ## Interfaz web
#
# La interfaz es la siguiente: https://console.groq.com/home
#
# ![image.png](attachment:image.png)
#
# ## Obtén tu API Key
#
# Para ejecutar el código en este notebook, necesitas generar una API Key en la interfaz:
#
# 1.  Visita [Groq ](https://console.groq.com/keys).
# 2.  Inicia sesión con tu cuenta de Google y directamente -> Create API KEY
# 3.  Copia la clave generada y pégala en la variable `groq_api_key` en la celda de código que se encuentra a continuación.
#
# ![image-2.png](attachment:image-2.png)
#
# Una vez que hayas configurado tu clave, podrás ejecutar el resto de las celdas para comunicarte con diferentes modelos
#
# ## Capa Gratuita
#
# Tenemos acceso a estos modelos:
#
# - openai/gpt-oss-20b
# - canopylabs/orpheus-v1-english
# - meta-llama/llama-4-maverick-17b-128e-instruct
# - allam-2-7b
# - meta-llama/llama-prompt-guard-2-86m
# - meta-llama/llama-4-scout-17b-16e-instruct
# - whisper-large-v3-turbo
# - openai/gpt-oss-safeguard-20b
# - meta-llama/llama-guard-4-12b
# - groq/compound-mini
# - groq/compound
# - qwen/qwen3-32b
# - canopylabs/orpheus-arabic-saudi
# - moonshotai/kimi-k2-instruct-0905
# - meta-llama/llama-prompt-guard-2-22m
# - llama-3.1-8b-instant
# - whisper-large-v3
# - llama-3.3-70b-versatile
# - moonshotai/kimi-k2-instruct
# - openai/gpt-oss-120b
#
# Los límites para cad modelo los puedes consultar en https://console.groq.com/dashboard/metrics
#
# ![image-3.png](attachment:image-3.png)

# %%
from groq import Groq

groq_api_key = "Tu API KEY aquí" # Reemplaza por la API KEY que te generes
client = Groq(api_key=groq_api_key)

completion = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
      {
        "role": "user",
        "content": "Explícame el sentido de la vida"
      }
    ],
    temperature=1,
    max_completion_tokens=1024,
    top_p=1,
    stream=True,
    stop=None
)

for chunk in completion:
    print(chunk.choices[0].delta.content or "", end="")
# Out:
# El sentido de la vida es un tema que ha intrigado a filósofos, científicos y pensadores a lo largo de la historia. Aunque no hay una respuesta única y definitiva, te presentaré algunas perspectivas y reflexiones que pueden ayudarte a entender mejor este concepto complejo.
#
# **Definición y perspectivas**
#
# El sentido de la vida se refiere a la búsqueda de significado y propósito en la existencia humana. Se trata de encontrar respuesta a preguntas como: "¿Por qué estamos aquí?", "¿Cuál es el propósito de la vida?", "¿Qué nos da sentido y dirección en la vida?".
#
# Existen diversas perspectivas sobre el sentido de la vida, que pueden ser clasificadas en:
#
# 1. **Religiosa**: Muchas creencias religiosas ofrecen una visión del sentido de la vida relacionada con la conexión con un poder superior, la búsqueda de la salvación o la realización de la voluntad divina.
# ...
